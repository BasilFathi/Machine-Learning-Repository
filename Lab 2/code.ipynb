# %%
import pandas as pd

df = pd.read_csv('precious_metals_historical_data.csv')
display(df.head())

print("Dataset Shape:", df.shape)
print(df.info())
# Out:
#          Date  Silver_Price  Gold_Price  Platinum_Price  Silver_Returns  \
# 0  2016-02-03         13.95  109.250000       84.940002             NaN
# 1  2016-02-04         14.17  110.570000       87.260002        0.015771
# 2  2016-02-05         14.34  112.320000       87.919998        0.011997
# 3  2016-02-08         14.59  113.830002       89.199997        0.017434
# 4  2016-02-09         14.51  113.580002       89.849998       -0.005483
#
#    Gold_Returns  Platinum_Returns  Gold_Silver_Ratio  Silver_Volatility_30d  \
# 0           NaN               NaN           7.831541                    NaN
# 1      0.012082          0.027313           7.803105                    NaN
# 2      0.015827          0.007564           7.832636                    NaN
# 3      0.013444          0.014559           7.801919                    NaN
# 4     -0.002196          0.007287           7.827705                    NaN
#
# ...
